# %%
from pathlib import Path

import pandas as pd
import numpy as np
import gensim as gs
import matplotlib.pyplot as plt

from dotenv import find_dotenv


# sys.path.append(os.path.dirname(find_dotenv()))

from cleaning_funcs import load_data, output_data

# %%
data = load_data('output/movie_list_current_clean.csv')

# %%
data.head()
# Out:
#     Month    Pick  IMDb ID                                            Movie  \
# 0  3/2019  Farzad   947798                                       Black Swan
# 1  4/2019     Jon   156887                                     Perfect Blue
# 2  5/2019  Steven   311113  Master and Commander: The Far Side of the World
# 3  6/2019  Farzad  2492296                                   Show Me A Hero
# 4  7/2019     Jon   147800                       10 Things I Hate About You
#
#    Year  IMDb Score  Sebastian  Jon  Dazraf  Average  \
# 0  2010         8.0        8.0  9.0     8.0      8.3
# 1  1997         8.0        9.0  9.0     7.0      8.3
# 2  2003         7.4        9.5  8.0     8.0      8.5
# 3  2015         8.1        7.0  8.0     8.0      7.7
# 4  1999         7.3        7.0  7.0     5.0      6.3
#
#                                                Notes  \
# 0                                    Inagural movie!
# 1                    Black Swan, but make it anime.
# 2        https://www.youtube.com/watch?v=mq1YthGFjRI
# 3  A 6 hour HBO miniseries...or was it 15 hours? ...
# 4                          Joey: American Viroth Tep
#
#                                              title  year  rating  \
# 0                                       Black Swan  2010     8.0
# 1                                     Perfect Blue  1997     8.0
# 2  Master and Commander: The Far Side of the World  2003     7.4
# 3                                   Show Me a Hero  2015     8.0
# 4                       10 Things I Hate About You  1999     7.3
#
#    plot_outline  plot  synopsis
# 0           NaN   NaN       NaN
# 1           NaN   NaN       NaN
# 2           NaN   NaN       NaN
# 3           NaN   NaN       NaN
# 4           NaN   NaN       NaN
